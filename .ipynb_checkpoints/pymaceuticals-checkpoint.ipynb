# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merged_research_df = pd.merge(mouse_metadata, study_results, how="left", on = 'Mouse ID')
# Display the data table for preview
merged_research_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
#nunique() was selected because it retruns the the number of unique values. 
#Count() could not be used on the cobined dataset because after the merge we have multiple lines for each mouse.
#Count could be used on the mice metadata file but nunuique needs to be used on the merged data frame.
#Based on the instructions for the homework, there appears to be a duplicate mouse or mice in the data

count_of_mice = merged_research_df['Mouse ID'].nunique()
count_of_mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
# To determine the duplicated mice in the combined dataset, the duplicated() panda function will be used
#The output reflects the instances that are duplicated

duplicated_mice = merged_research_df[merged_research_df.duplicated(['Mouse ID', 'Timepoint'])]
duplicated_mice
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID.
merged_research_df[merged_research_df['Mouse ID'] == 'g989']
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
#Tried using 
#clean_merged_research_df=merged_research_df.drop_duplicates(['Mouse ID' , 'Timepoint'], False)
#clean_merged_research_df
#After attempting the use of drop_duplicates the count of the mice did not decrease

clean_merged_research_df = merged_research_df[merged_research_df['Mouse ID'] != 'g989']
clean_merged_research_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
count_of_mice_clean = clean_merged_research_df['Mouse ID'].nunique()
count_of_mice_clean

#The count of nunique mice dropped from 249 ro 248
# Out:
# 248

# %%
clean_merged_research_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

#Calculated each statistic individually using the groupby on Drug Regiman to calculate the statistics of the Tumor Volume
#Calculation based on the clean_merged_research_df that removed the duplicated mouse data.

mean = clean_merged_research_df.groupby("Drug Regimen")['Tumor Volume (mm3)'].mean()
median = clean_merged_research_df.groupby("Drug Regimen")['Tumor Volume (mm3)'].median()
variance = clean_merged_research_df.groupby("Drug Regimen")['Tumor Volume (mm3)'].var()
standard_deviation = clean_merged_research_df.groupby("Drug Regimen")['Tumor Volume (mm3)'].std()
sem = clean_merged_research_df.groupby("Drug Regimen")['Tumor Volume (mm3)'].sem()

#Create a summary statistis dataframe uimng the pd.DataFrame funtion. 
summary_statistics_df = pd.DataFrame({"Mean": mean, "Median": median, "Variance": variance, "Standard Deviation": standard_deviation, "SEM": sem}).reset_index()
#added the reset index so that drug regimen would become a column and not the index
summary_statistics_df
# Out:
#   Drug Regimen       Mean     Median   Variance  Standard Deviation       SEM
# 0    Capomulin  40.675741  41.557809  24.947764            4.994774  0.329346
# 1     Ceftamin  52.591172  51.776157  39.290177            6.268188  0.469821
# 2    Infubinol  52.884795  51.820584  43.128684            6.567243  0.492236
# 3     Ketapril  55.235638  53.698743  68.553577            8.279709  0.603860
# 4     Naftisol  54.331565  52.509285  66.173479            8.134708  0.596466
# 5      Placebo  54.033581  52.288934  61.168083            7.821003  0.581331
# 6     Propriva  52.320930  50.446266  43.852013            6.622085  0.544332
# 7     Ramicane  40.216745  40.673236  23.486704            4.846308  0.320955
# 8     Stelasyn  54.233149  52.431737  59.450562            7.710419  0.573111
# 9    Zoniferol  53.236507  51.818479  48.533355            6.966589  0.516398

# %%
clean_merged_research_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Using the aggregation method, produce the same summary statistics in a single line

summary_statistics_agg = clean_merged_research_df.groupby(['Drug Regimen']).agg(
    avg = ('Tumor Volume (mm3)','mean'),
    median = ('Tumor Volume (mm3)','median'),
    variance = ('Tumor Volume (mm3)','var'),
    standard_deviation = ('Tumor Volume (mm3)','std'),
    sem = ('Tumor Volume (mm3)','sem')
).reset_index()
                                                          
summary_statistics_agg
# Out:
#   Drug Regimen        avg     median   variance  standard_deviation       sem
# 0    Capomulin  40.675741  41.557809  24.947764            4.994774  0.329346
# 1     Ceftamin  52.591172  51.776157  39.290177            6.268188  0.469821
# 2    Infubinol  52.884795  51.820584  43.128684            6.567243  0.492236
# 3     Ketapril  55.235638  53.698743  68.553577            8.279709  0.603860
# 4     Naftisol  54.331565  52.509285  66.173479            8.134708  0.596466
# 5      Placebo  54.033581  52.288934  61.168083            7.821003  0.581331
# 6     Propriva  52.320930  50.446266  43.852013            6.622085  0.544332
# 7     Ramicane  40.216745  40.673236  23.486704            4.846308  0.320955
# 8     Stelasyn  54.233149  52.431737  59.450562            7.710419  0.573111
# 9    Zoniferol  53.236507  51.818479  48.533355            6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
#Creare a new data frame using the clean data datafraem grouped by Drug Regimen and that also includes a count function
#Once created, a df will be created that only contains the the count of Mouse ID and Greg Regimen

drug_treatment_data = pd.DataFrame(clean_merged_research_df.groupby(['Drug Regimen']).count()).reset_index()
drug_treatment_data_df = drug_treatment_data[['Drug Regimen','Timepoint']]

drug_treatment_data_df
# Out:
#   Drug Regimen  Timepoint
# 0    Capomulin        230
# 1     Ceftamin        178
# 2    Infubinol        178
# 3     Ketapril        188
# 4     Naftisol        186
# 5      Placebo        181
# 6     Propriva        148
# 7     Ramicane        228
# 8     Stelasyn        181
# 9    Zoniferol        182

# %%
#Create the bar chart

drug_treatment_data_df.plot(x='Drug Regimen', y='Timepoint',kind="bar",figsize=(10,3),title='Count of Drug Treatments')

# %%
drug_treatment_data_df
# Out:
#   Drug Regimen  Timepoint
# 0    Capomulin        230
# 1     Ceftamin        178
# 2    Infubinol        178
# 3     Ketapril        188
# 4     Naftisol        186
# 5      Placebo        181
# 6     Propriva        148
# 7     Ramicane        228
# 8     Stelasyn        181
# 9    Zoniferol        182

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
# Chart our data, give it a title, and label the axes
plt.bar(x=drug_treatment_data_df['Drug Regimen'],height=drug_treatment_data_df['Timepoint'])
plt.xticks(rotation=90)
plt.xlabel("Drug Regimen")
plt.ylabel("Timepoint")

plt.show()

# %%
#Review of the clean merged research dataframe
clean_merged_research_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
#First, let's groups by Sex and do a count
mice_gender_df = clean_merged_research_df.groupby(['Sex']).count().reset_index()
mice_gender_df
# Out:
#       Sex  Mouse ID  Drug Regimen  Age_months  Weight (g)  Timepoint  \
# 0  Female       922           922         922         922        922
# 1    Male       958           958         958         958        958
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0                 922               922
# 1                 958               958

# %%
#Drop the dataframe down to two columns - Sex and Mouse ID
#This becomes the clean and simple data frame I am going to use with the Pandas
mice_gender_df=mice_gender_df[['Sex','Mouse ID']]
mice_gender_df
# Out:
#       Sex  Mouse ID
# 0  Female       922
# 1    Male       958

# %%
#Define the pie chart using Pandas

mice_gender_df.plot(kind='pie',y='Mouse ID',autopct= '%1.00f%%', shadow=True, 
                    labels=mice_gender_df["Sex"], legend=False, fontsize=16)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
#Convert the dataframe down to a list
mice_sex_count= (clean_merged_research_df.groupby(["Sex"])["Mouse ID"].count()).tolist()
mice_sex_count
# Out:
# [922, 958]

# %%
#Details of the pie chart
labels = ["Females","Males"]
colors = ["pink","blue"]
explode = (0.0, 0)

#Create the pie chart
plt.pie(mice_sex_count, labels=labels, colors=colors, explode=explode, autopct="%1.0f%%",shadow=True, startangle=160)
plt.axis("equal")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# Now that is getting much more complicated, I am going to break all of this down into smaller steps

#################Data Preparation########################
#Let's review current cleaned data data frame
#Note: Based on the approach I have taken, I don't have to merge with the final dataset to get the final tumor volumeat the last timepoint.




clean_merged_research_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
#Let's identify the greatest time points for each mouse
#Going to to this by sorting the clean dataframe using .sort_values()
clean_merged_research_df_sorted=clean_merged_research_df.sort_values(['Timepoint'], ascending=False)
clean_merged_research_df_sorted
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 1892     z969     Naftisol    Male           9          30         45
# 1344     p136    Zoniferol  Female           5          28         45
# 874      g296    Zoniferol  Female          14          29         45
# 884      g497     Ketapril    Male          19          28         45
# 360      g316    Capomulin  Female          22          22         45
# ...       ...          ...     ...         ...         ...        ...
# 1170     m269     Stelasyn  Female          22          28          0
# 1164     m133     Naftisol  Female           2          26          0
# 1163     l872      Placebo    Male          19          30          0
# 1153     l733     Ceftamin  Female           4          30          0
# 953      i635     Propriva    Male          21          26          0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1892           73.867845                 4
# ...

# %%
#Based on the above sort, it appears that the latest timepoint is 45
#Question: What if the latest time point for some mice is less that 45?  Is there a different way to approach?

#Going with the assumption of 45 as the latest time point, I am going to create a new dataframe with just 45 as the timepoint
#going to try to use the .loc funtion to try to pull that data out
timepoint_max_cleaned_df=clean_merged_research_df_sorted.loc[clean_merged_research_df_sorted['Timepoint'] == 45]
timepoint_max_cleaned_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 1892     z969     Naftisol    Male           9          30         45
# 1344     p136    Zoniferol  Female           5          28         45
# 874      g296    Zoniferol  Female          14          29         45
# 884      g497     Ketapril    Male          19          28         45
# 360      g316    Capomulin  Female          22          22         45
# ...       ...          ...     ...         ...         ...        ...
# 440      i557    Capomulin  Female           1          24         45
# 1703     w422     Ketapril  Female          18          26         45
# 587      a963     Stelasyn  Female          23          27         45
# 1518     s337    Zoniferol    Male          14          27         45
# 550      a699     Propriva  Female           5          28         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1892           73.867845                 4
# ...

# %%
#Now going to reset the index of the time_point_max_cleaned_df using the reset_index function
timepoint_max_cleaned_df.head().reset_index()
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0   1892     z969     Naftisol    Male           9          30         45
# 1   1344     p136    Zoniferol  Female           5          28         45
# 2    874     g296    Zoniferol  Female          14          29         45
# 3    884     g497     Ketapril    Male          19          28         45
# 4    360     g316    Capomulin  Female          22          22         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           73.867845                 4
# 1           63.488697                 2
# 2           68.163195                 4
# 3           69.872251                 2
# 4           40.159220                 2

# %%
#Next, I am going to creat a data frame for each of the drugs
#A data frame will be created for Capomulin, Ramicane, Infubinol, and Ceftamin
#naming convention will be first three characters of the drug, tp_max for max time point
cap_tp_max_df=timepoint_max_cleaned_df[timepoint_max_cleaned_df["Drug Regimen"].isin(["Capomulin"])].reset_index()
ram_tp_max_df=timepoint_max_cleaned_df[timepoint_max_cleaned_df["Drug Regimen"].isin(["Ramicane"])].reset_index()
inf_tp_max_df=timepoint_max_cleaned_df[timepoint_max_cleaned_df["Drug Regimen"].isin(["Infubinol"])].reset_index()
cef_tp_max_df=timepoint_max_cleaned_df[timepoint_max_cleaned_df["Drug Regimen"].isin(["Ceftamin"])].reset_index()

# %%
#Have created a dataframe for each of the drug regimens. 
#Following sections will simply validate the data and the index will be reset at the end after validating the data.

# %%
#Validate Capomulin df
cap_tp_max_df
# Out:
#     index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0     360     g316    Capomulin  Female          22          22         45
# 1     124     y793    Capomulin    Male          17          17         45
# 2     350     v923    Capomulin  Female          19          21         45
# 3     134     r554    Capomulin  Female           8          17         45
# 4     337     j119    Capomulin  Female           7          23         45
# 5     144     m957    Capomulin  Female           3          19         45
# 6     370     s710    Capomulin  Female           1          23         45
# 7     390     r944    Capomulin    Male          12          25         45
# 8     104     u364    Capomulin    Male          18          17         45
# 9     380     l509    Capomulin    Male          17          21         45
# 10    244     g288    Capomulin    Male           3          19         45
# ...

# %%
ram_tp_max_df
# Out:
#     index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0     327     a411     Ramicane    Male           3          22         45
# 1     114     n364     Ramicane    Male           4          17         45
# 2     410     u196     Ramicane    Male          18          25         45
# 3     400     e662     Ramicane    Male           8          24         45
# 4      94     j913     Ramicane  Female           4          17         45
# 5     214     a520     Ramicane    Male          13          21         45
# 6     184     i177     Ramicane    Male          10          18         45
# 7     254     i334     Ramicane  Female           8          20         45
# 8     194     j989     Ramicane    Male           8          19         45
# 9     234     r811     Ramicane    Male           9          19         45
# 10    154     c758     Ramicane    Male           9          17         45
# ...

# %%
#Validate Infubinol
inf_tp_max_df
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0    800     e476    Infubinol    Male          23          26         45
# 1    834     f345    Infubinol    Male          23          26         45
# 2   1872     z581    Infubinol  Female          24          25         45
# 3   1053     k483    Infubinol  Female          20          30         45
# 4   1813     y163    Infubinol  Female          17          27         45
# 5    463     a203    Infubinol  Female          20          23         45
# 6    473     a251    Infubinol  Female          21          25         45
# 7    637     c139    Infubinol    Male          11          28         45
# 8    540     a685    Infubinol    Male           8          30         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           62.435404                 1
# 1           60.918767                 1
# 2           62.754451                 3
# 3           66.196912                 3
# ...

# %%
#Validate Ceftamin
cef_tp_max_df
# Out:
#     index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0    1855     y865     Ceftamin    Male          23          26         45
# 1    1379     p438     Ceftamin  Female          11          26         45
# 2    1797     x822     Ceftamin    Male           3          29         45
# 3     993     j296     Ceftamin  Female          24          30         45
# 4    1112     l471     Ceftamin  Female           7          28         45
# 5    1260     o287     Ceftamin    Male           2          28         45
# 6    1132     l661     Ceftamin    Male          18          26         45
# 7    1162     l733     Ceftamin  Female           4          30         45
# 8    1773     x581     Ceftamin  Female          19          28         45
# 9    1033     k210     Ceftamin    Male          15          28         45
# 10   1845     y769     Ceftamin  Female           6          27         45
# ...

# %%
#Note: From the above validation and breaking each regimen into it's own data frame, notice that Infubinol had fewer mice in the study.
#Next, I am going to convert tumor volume for each of the data frames of each regimen into a list so that I can create quartiles

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
#Captolin tumor data
cap_tp_list=cap_tp_max_df.sort_values(['Tumor Volume (mm3)'],ascending=True).reset_index()
cap_tp_list=cap_tp_list['Tumor Volume (mm3)']
cap_tp_list
# Out:
# 0     23.343598
# 1     28.430964
# 2     28.484033
# 3     31.023923
# 4     31.896238
# 5     32.377357
# 6     33.329098
# 7     34.455298
# 8     36.041047
# 9     37.074024
# 10    37.311846
# 11    38.125164
# 12    38.846876
# 13    38.939633
# 14    38.982878
# 15    40.159220
# 16    40.658124
# 17    40.728578
# 18    41.483008
# 19    41.581521
# 20    47.685963
# Name: Tumor Volume (mm3), dtype: float64

# %%
#quartiles, lowerq, upperq and iqr calculated for Capomulin
quartiles = cap_tp_list.quantile([.25,.5,.75])
lowerq_cap = quartiles[0.25]
upperq_cap = quartiles[0.75]
medq_cap = quartiles[0.5]
iqr_cap = upperq_cap - lowerq_cap

print(f"The lower quartile of Tumor Volume (mm3) for Capomulin is: {lowerq_cap}")
print(f"The upper quartile of Tumor Volume (mm3) for Capomulin is: {upperq_cap}")
print(f"The interquartile range of Tumor Volume (mm3) for Capomulin is: {iqr_cap}")
print(f"The median range of Tumor Volume (mm3) for Capomulin is: {medq_cap}")

lower_bound_cap = lowerq_cap - (1.5*iqr_cap)
upper_bound_cap = upperq_cap + (1.5*iqr_cap)

print(f"Values below {lower_bound_cap} could be Campolin outliers.")
print(f"Values above {upper_bound_cap} could be Campolin outliers.")
# Out:
# The lower quartile of Tumor Volume (mm3) for Capomulin is: 32.37735684
# The upper quartile of Tumor Volume (mm3) for Capomulin is: 40.1592203
# The interquartile range of Tumor Volume (mm3) for Capomulin is: 7.781863460000004
# The median range of Tumor Volume (mm3) for Capomulin is: 37.31184577
# Values below 20.70456164999999 could be Campolin outliers.
# Values above 51.83201549 could be Campolin outliers.

# %%
#Ramicane tumor data
ram_tp_list=ram_tp_max_df.sort_values(['Tumor Volume (mm3)'],ascending=True).reset_index()
ram_tp_list=ram_tp_list['Tumor Volume (mm3)']
ram_tp_list
# Out:
# 0     22.050126
# 1     29.128472
# 2     30.276232
# 3     30.564625
# 4     30.638696
# 5     31.095335
# 6     31.560470
# 7     32.978522
# 8     33.397653
# 9     33.562402
# 10    36.134852
# 11    36.374510
# 12    37.225650
# 13    37.311236
# 14    38.407618
# 15    38.810366
# 16    40.659006
# 17    40.667713
# 18    43.047543
# 19    45.220869
# Name: Tumor Volume (mm3), dtype: float64

# %%
#quartiles, lowerq, upperq and iqr calculated for Ramicane
quartiles = ram_tp_list.quantile([.25,.5,.75])
lowerq_ram = quartiles[0.25]
upperq_ram = quartiles[0.75]
medq_ram = quartiles[0.5]
iqr_ram = upperq_ram - lowerq_ram

print(f"The lower quartile of Tumor Volume (mm3) for Ramicane is: {lowerq_ram}")
print(f"The upper quartile of Tumor Volume (mm3) for Ramicane is: {upperq_ram}")
print(f"The interquartile range of Tumor Volume (mm3) for Ramicane is: {iqr_ram}")
print(f"The median range of Tumor Volume (mm3) for Ramicane is: {medq_ram}")

lower_bound_ram = lowerq_ram - (1.5*iqr_ram)
upper_bound_ram = upperq_ram + (1.5*iqr_ram)

print(f"Values below {lower_bound_ram} could be Ramicane outliers.")
print(f"Values above {upper_bound_ram} could be Ramicane outliers.")
# Out:
# The lower quartile of Tumor Volume (mm3) for Ramicane is: 30.981175224999998
# The upper quartile of Tumor Volume (mm3) for Ramicane is: 38.508305307499995
# The interquartile range of Tumor Volume (mm3) for Ramicane is: 7.527130082499998
# The median range of Tumor Volume (mm3) for Ramicane is: 34.848627300000004
# Values below 19.690480101250003 could be Ramicane outliers.
# Values above 49.79900043124999 could be Ramicane outliers.

# %%
#Infubinol tumor data
inf_tp_list=inf_tp_max_df.sort_values(['Tumor Volume (mm3)'],ascending=True).reset_index()
inf_tp_list=inf_tp_list['Tumor Volume (mm3)']
inf_tp_list
# Out:
# 0    60.918767
# 1    62.435404
# 2    62.754451
# 3    65.525743
# 4    66.083066
# 5    66.196912
# 6    67.685569
# 7    67.973419
# 8    72.226731
# Name: Tumor Volume (mm3), dtype: float64

# %%
#quartiles, lowerq, upperq and iqr calculated for Infubinol
quartiles = inf_tp_list.quantile([.25,.5,.75])
lowerq_inf = quartiles[0.25]
upperq_inf = quartiles[0.75]
medq_inf = quartiles[0.5]
iqr_inf = upperq_inf - lowerq_inf

print(f"The lower quartile of Tumor Volume (mm3) for Infubinol is: {lowerq_inf}")
print(f"The upper quartile of Tumor Volume (mm3) for Infubinol is: {upperq_inf}")
print(f"The interquartile range of Tumor Volume (mm3) for Infubinol is: {iqr_inf}")
print(f"The median range of Tumor Volume (mm3) for Infubinol is: {medq_inf}")

lower_bound_inf = lowerq_inf - (1.5*iqr_inf)
upper_bound_inf = upperq_inf + (1.5*iqr_inf)

print(f"Values below {lower_bound_inf} could be Infubinol outliers.")
print(f"Values above {upper_bound_inf} could be Infubinol outliers.")
# Out:
# The lower quartile of Tumor Volume (mm3) for Infubinol is: 62.75445141
# The upper quartile of Tumor Volume (mm3) for Infubinol is: 67.68556862
# The interquartile range of Tumor Volume (mm3) for Infubinol is: 4.9311172099999965
# The median range of Tumor Volume (mm3) for Infubinol is: 66.08306589
# Values below 55.35777559500001 could be Infubinol outliers.
# Values above 75.08224443499999 could be Infubinol outliers.

# %%
#Ceftamin tumor data
cef_tp_list=cef_tp_max_df.sort_values(['Tumor Volume (mm3)'],ascending=True).reset_index()
cef_tp_list=cef_tp_list['Tumor Volume (mm3)']
cef_tp_list
# Out:
# 0     59.741901
# 1     59.851956
# 2     61.386660
# 3     61.433892
# 4     61.849023
# 5     62.999356
# 6     64.299830
# 7     64.634949
# 8     64.729837
# 9     67.527482
# 10    67.748662
# 11    68.594745
# 12    68.923185
# Name: Tumor Volume (mm3), dtype: float64

# %%
#quartiles, lowerq, upperq and iqr calculated for Ceftamin
quartiles = cef_tp_list.quantile([.25,.5,.75])
lowerq_cef = quartiles[0.25]
upperq_cef = quartiles[0.75]
medq_cef = quartiles[0.5]
iqr_cef = upperq_cef - lowerq_cef

print(f"The lower quartile of Tumor Volume (mm3) for Ceftamin is: {lowerq_cef}")
print(f"The upper quartile of Tumor Volume (mm3) for Ceftamin is: {upperq_cef}")
print(f"The interquartile range of Tumor Volume (mm3) for Ceftamin is: {iqr_cef}")
print(f"The median range of Tumor Volume (mm3) for Ceftamin is: {medq_cef}")

lower_bound_cef = lowerq_cef - (1.5*iqr_cef)
upper_bound_cef = upperq_cef + (1.5*iqr_cef)

print(f"Values below {lower_bound_cef} could be Ceftamin outliers.")
print(f"Values above {upper_bound_cef} could be Ceftamin outliers.")
# Out:
# The lower quartile of Tumor Volume (mm3) for Ceftamin is: 61.43389223
# The upper quartile of Tumor Volume (mm3) for Ceftamin is: 67.52748237
# The interquartile range of Tumor Volume (mm3) for Ceftamin is: 6.093590140000003
# The median range of Tumor Volume (mm3) for Ceftamin is: 64.29983003
# Values below 52.29350701999999 could be Ceftamin outliers.
# Values above 76.66786758 could be Ceftamin outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
